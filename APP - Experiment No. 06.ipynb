# %% [markdown]
# #**Name :** Pawan Gosavi
# #**Class :** FYBSc CS
# #**Roll No. :** 01

# %% [markdown]
# # **APP - Practical No. 06**
#
# ## **Aim :** Write a GUI Program in Python to design application that demonstrates Different fonts and colours, Different Layout Managers, Event Handling.

# %% [markdown]
# # **Python GUI – tkinter**

# %% [markdown]
#   Python offers multiple options for developing GUI (Graphical User Interface). Out of all the GUI methods, tkinter is the most commonly used method. It is a standard Python interface to the Tk GUI toolkit shipped with Python. Python with tkinter is the fastest and easiest way to create the GUI applications. Creating a GUI using tkinter is an easy task.
#
#   To create a tkinter app:
#
# * Importing the module – tkinter
# * Create the main window (container)
# * Add any number of widgets to the main window
# * Apply the event Trigger on the widgets.
#
#
#   Importing tkinter is same as importing any other module in the Python code. Note that the name of the module in Python 2.x is ‘Tkinter’ and in Python 3.x it is ‘tkinter’.
#
#   `import tkinter`
#
#
#   There are two main methods used which the user needs to remember while creating the Python application with GUI.
#
# *Tk(screenName=None,  baseName=None,  className=’Tk’,  useTk=1):* To create a main window, tkinter offers a method ‘Tk(screenName=None,  baseName=None,  className=’Tk’,  useTk=1)’. To change the name of the window, you can change the className to the desired one. The basic code used to create the main window of the application is:
#
# `m=tkinter.Tk() where m is the name of the main window object`
#
#   mainloop(): There is a method known by the name mainloop() is used when your application is ready to run. mainloop() is an infinite loop used to run the application, wait for an event to occur and process the event as long as the window is not closed.
#
# ```
# import tkinter
# m = tkinter.Tk()
# '''
# widgets are added here
# '''
# m.mainloop()
# ```
#
#   tkinter also offers access to the geometric configuration of the widgets which can organize the widgets in the parent windows. There are mainly three geometry manager classes class.
#
# * pack() method:It organizes the widgets in blocks before placing in the parent widget.
# * grid() method:It organizes the widgets in grid (table-like structure) before placing in the parent widget.
# * place() method:It organizes the widgets by placing them on specific positions directed by the programmer.

# %% [markdown]
# ###**Configuring the widget with various options.**

# %%
# Try to configure the widget with various options like:
# bg = "red", family = "times", size = 18

# imports
import tkinter as tk
# from tkinter import ttk

# Create instance
win = tk.Tk()   

# Add a title       
win.title("APP Practical No. 06")

# Add a Canvas size
# win.geometry("300x300")

# Adding a Label
my_label = tk.Label(win, text = "Pawan Gosavi", bg = "red",
                 fg = "White", font=('times', 18), width = 25)
my_label.pack()

# Start GUI
win.mainloop()

# %% [markdown]
# ### **Output :**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Experimenting with other widget types like Message, Button, Entry, Checkbutton, Radiobutton, Scale etc.**

# %%
# Try to change the widget type and configuration options
# to experiment with other widget types like Message, Button,
# Entry, Checkbutton, Radiobutton, Scale etc.

# imports
import tkinter as tk
# from tkinter import ttk

# Create instance
win = tk.Tk()   

# Add a title       
win.title('APP Practical No. 06')

# Add a size
win.geometry('400x600')

# Make it Non Resizeable
win.resizable(False, False)

# Adding a Message
my_message = tk.Message(win, text = 'Registration Form',
                        bg = 'White', fg = 'Red', font=('Comic Sans MS', 18),
                        relief = "solid", width = 300)
my_message.pack(pady = 5)

def submitform():
    fname = 'Name : ' + str(name.get())
    femail = 'Email : ' + str(email.get())
    fpass = 'Password : ' + str(password.get())
    fgender = 'Gender : ' + str(gender.get())
    fage = 'Age : ' + str(age.get())
    print("\nx--------- Registration Details ---------x\n")
    print(fname)
    print(femail)
    print(fpass)
    print(fgender)
    print(fage)
    print("\nx--------- Submission Successfull! ---------x\n")
    L6.config(text = 'Dear ' + str(name.get()) + ', Form Submitted Successfully!')
    E1.config(state = 'disabled')
    E2.config(state = 'disabled')
    E3.config(state = 'disabled')
    R1.config(state = 'disabled')
    R2.config(state = 'disabled')
    S1.config(state = 'disabled')
    C1.config(state = 'disabled')
    B1.config(state = 'disabled')
    
def tnc():
    ftandc = str(tandc.get())
    if ftandc == '1':
        B1.config(state = 'active')
    else:
        B1.config(state = 'disabled')

def rb():
    fgender = str(gender.get())
    if fgender == 'Male':
        R1.config(fg = 'Blue')
        R2.config(fg = 'Black')
    else:
        R2.config(fg = 'Blue')
        R1.config(fg = 'Black')

name = tk.StringVar()
email = tk.StringVar()
password = tk.StringVar()
tandc = tk.StringVar()
gender = tk.StringVar()
age = tk.StringVar()

# Adding a Labels
L1 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Full Name')
L1.pack(pady = 3)

E1 = tk.Entry(win, textvariable = name, justify = 'center',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E1.pack(pady = 3)

L2 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Email')
L2.pack(pady = 3)

E2 = tk.Entry(win, textvariable = email, justify = 'center',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E2.pack(pady = 3)

L3 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Password')
L3.pack(pady = 3)

E3 = tk.Entry(win, textvariable = password, justify = 'center', show='*',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E3.pack(pady = 3)

L4 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Gender')
L4.pack(pady = 3)

R1 = tk.Radiobutton(win, text = 'Male', font=('Comic Sans MS', 12),
                    value = 'Male', variable = gender, command = rb)
R1.pack(pady = 3)

R2 = tk.Radiobutton(win, text = 'Female', font=('Comic Sans MS', 12),
                    value = 'Female', variable = gender, command = rb)
R2.pack(pady = 3)

L5 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Age')
L5.pack(pady = 3)

S1 = tk.Scale(win, variable = age, from_ = 1, to = 100,
              orient = 'horizontal', length = 300, bd = 2,
              font=('Comic Sans MS', 12), fg = 'Blue')
S1.pack(pady = 3)

C1 = tk.Checkbutton(win, command = tnc, font=('Comic Sans MS', 12),
                    text = 'I Accept All Terms & Conditions.',
                    variable = tandc, fg = 'Red')
C1.pack(pady = 3)

B1 = tk.Button(win, text = 'Submit', state = 'disabled',
               font=('Comic Sans MS', 12), command = submitform)
B1.pack(pady = 3)

L6 = tk.Label(win, font=('Comic Sans MS', 12), fg = 'Blue')
L6.pack(pady = 3)

# Start GUI
win.mainloop()
# Out:
# x--------- Registration Details ---------x
#
# Name : Pawan Gosavi
# Email : pawanajaygosavi@mes.ac.in
# Password : Pawan@123
# Gender : Male
# Age : 23
#
# x--------- Submission Successfull! ---------x

# %% [markdown]
# ### **Output :**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Student's Activity**

# %% [markdown]
# ### **A TKinter Canvas with Name printed as Label**

# %%
# Try to configure & Create Your Name using the widget with various options like:
# bg = "Navy", family = "Cambria", size = 30

# imports
import tkinter as tk
# from tkinter import ttk

# Create instance
win = tk.Tk()   

# Add a title       
win.title("APP Practical No. 06")

# Add a Canvas size
# win.geometry("300x300")

# Adding a Label
my_label = tk.Label(win, text = "All is Well!", bg = "Navy",
                 fg = "Yellow", font=('Cambria', 30), width = 25)
my_label.pack()

# Start GUI
win.mainloop()

# %% [markdown]
# ### **Output :**
#
# ![image.png](data:image/png;base64,...)
